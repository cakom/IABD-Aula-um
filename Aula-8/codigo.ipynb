# %%
# !pip install numpy matplotlib seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Aula 8 - Exemplo de Arvores de Decisão

#importar biblioteca 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split #treino e teste
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#criando  o conjundo  de dados 
notas = np.array([8,6,5,9,4,3,7,2,1,5,6,9,8])

classes = np.array(['bom','ruim','ruim','bom','pessimo','pessimo','bom','pessimo','pessimo','ruim','ruim','bom','bom'])

# %%
#dividindo o conjunto de dados em treino e teste
notas_treinos, notas_teste, classes_treino, classes_teste = train_test_split(
    notas.reshape(-1,1), classes.reshape(-1,1), test_size=0.2, random_state=42)

    #80% treino e 20% teste

# %%
modelo = DecisionTreeClassifier() #criando o modelo
modelo.fit(notas_treinos, classes_treino) #treinando o modelo
# Out:
# DecisionTreeClassifier()

# %%
print ("notas teste", notas_teste  )
print ("classes teste", classes_teste  )
# Out:
# notas teste [[9]
#  [5]
#  [8]]
# classes teste [['bom']
#  ['ruim']
#  ['bom']]

# %%
#realizando a predição 
modelo.predict(notas_teste)
# Out:
# array(['bom', 'ruim', 'bom'], dtype='<U7')

# %%
#realizando predição com uma nova nota
modelo.predict(np.array([[6]])) # realiza predições de notas individuais
# Out:
# array(['ruim'], dtype='<U7')

# %%
modelo.predict(np.array([7.5]).reshape (-1,1)) # realiza predições de notas individuais
# Out:
# array(['bom'], dtype='<U7')

# %%
fig = plt.figure(figsize=(10,12))# cria uma figura 10x12
tree.plot_tree(modelo,feature_names=notas.tolist(), class_names=classes.tolist(), filled=True) #     plota a árvore de decisão
plt.title ("Árvore de Decisão -para classifiar bebidas de acordo com nota")
fontsize=16
plt.show()

# %%
plt.figure(figsize=(10,8))# cria uma figura 10x12
plt.title('box plot das notas  ')
sns.boxplot(x=classes,y=notas,palette=['green','orange','red'])
# Out:
# C:\Users\dsadm\AppData\Local\Temp\ipykernel_58968\1907017282.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=classes,y=notas,palette=['green','orange','red'])
# <Axes: title={'center': 'box plot das notas  '}>

# %%
#grafico de barras
plt.figure(figsize=(10,8))
sns.barplot(y=notas,x=classes,palette=['green','yellow','red'])
plt.title('Notas das bebidas',fontsize=16)
plt.xlabel('classificação',fontsize=16)
plt.ylabel('notas',fontsize=16)
# Out:
# C:\Users\dsadm\AppData\Local\Temp\ipykernel_58968\1343264584.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=notas,x=classes,palette=['green','yellow','red'])
# Text(0, 0.5, 'notas')
